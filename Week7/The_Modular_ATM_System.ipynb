# %% [markdown]
# <a href="https://colab.research.google.com/github/martinrabadan2885/ThinkPythonAssignments/blob/main/Week7/The_Modular_ATM_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#   pin = 1234
#   user_pin = int(input("Please enter your PIN: "))
#    - Return True
#   while user_pin == pin:
#   print("Correct PIN. Access granted.")
#    - Return False
#    while user_pin != pin:
#   rint("Incorrect PIN. Access denied.")
#  user_pin = int(input("Please enter your PIN: "))
# 2. Define withdraw(balance, amount):
# def current_balance = 500
# withdrawn_amount = int(input("Please enter the amount you would like to withdraw: "))
#    - Check if enough money exists
# if withdrawn_amount <= 500:
#  print("Withdraw complete")
#    - Return the new (or old) balance
# if withdrawn_amount <= 500:
#  print("current_balance - withdrawn_amount")


# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500
# 2. Call verify_pin()
pin = 1234
user_pin = int(input("Please enter your PIN: "))
while user_pin != pin:
  print("Incorrect PIN. Try Again.")
  user_pin = int(input("Please enter your PIN: "))
print("Pin Verified.")
# 3. Get withdrawal amount from user input
withdrawn_amount = int(input("Please enter the amount you would like to withdraw: "))
# 4. Update current_balance by calling withdraw()
if withdrawn_amount <= current_balance:
  print("Withdraw Successful")
  current_balance = current_balance - withdrawn_amount
  print ("Current_balence", current_balance)
# 5. Print the final balance
# Out:
# Please enter your PIN: 0000
# Incorrect PIN. Try Again.
# Please enter your PIN: 1234
# Pin Verified.
# Please enter the amount you would like to withdraw: 150
# Withdraw Successful
# Current_balence 350
