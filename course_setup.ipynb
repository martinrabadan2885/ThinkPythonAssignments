# %% [markdown]
# <a href="https://colab.research.google.com/github/martinrabadan2885/ThinkPythonAssignments/blob/main/course_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3*3)

my_name = input("Give me a name: ")
print(my_name)
# Out:
# 9
# Give me a name: Mickey Mouse
# Mickey Mouse
