# %% [markdown]
# <a href="https://colab.research.google.com/github/martinrabadan2885/ThinkPythonAssignments/blob/main/Week3/The_Cinema_Pricing_Logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_ticket(age, hour):
    #If age <= 12 or age>= 65, set price to 8
    if age <= 12 or age >= 65:
        price = 8
    else:
        price = 12
    return price

# Ask user for age
user_age = int(input("What is your age? "))

# Ask user for movie hour (24-hour format)
user_hour = int(input("What hour did you watch the movie? "))

# Call the calculate_ticket function with the obtained inputs
ticket_price = calculate_ticket(user_age, user_hour)

# Print the calculated ticket price
print("The ticket price is $" + str(ticket_price))
# Out:
# What is your age? 10
# What hour did you watch the movie? 19
# The ticket price is $8
