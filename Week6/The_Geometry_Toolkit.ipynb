# %% [markdown]
# <a href="https://colab.research.google.com/github/martinrabadan2885/ThinkPythonAssignments/blob/main/Week6/The_Geometry_Toolkit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
# FUNCTION DEFINITIONS
# 1. Define area(radius):
def area(radius):
  area= math.pi * radius** 2
  return area

# 2. Define circumference(radius):
def circumference(radius):
  circumference= 2 * math.pi * radius
  return circumference

# 3. Define volume(radius, height):
def volume(radius, height):
#    - Call area(radius) and multiply by height.
  r_area=area(radius)
  return r_area * height
  return volume
#    - Return the result.

# PROGRAM LOGIC

# Ask the user for the radius
radius = float(input("Enter the radius of the circle: "))

# Call and print area(radius) and circumference(radius).
print("area:", area((radius)))
print("circumference:", circumference((radius)))
# Ask the user for height
height = float(input("Enter the height of the circle: "))
def area_height(height):
  return volume

# Call and print volume.
calculate_volume = volume(radius, height)
print("cylinder volume:", volume(radius, height))
# Out:
# Enter the radius of the circle: 11
# area: 380.132711084365
# circumference: 69.11503837897544
# Enter the height of the circle: 100
# cylinder volume: 38013.2711084365
